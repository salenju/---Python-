# %% [markdown]
# # 1.6.0 Matplotlib是什么？
#  Matplotlib用于绘制图形的库

# %% [markdown]
# # 1.6.1 绘制简单图形
# 可以使用matplotlib的pyplot模块绘制图形

# %%
# 绘制sin函数曲线
import numpy as np
import matplotlib.pyplot as plt

# 生成数据
x1 = np.arange(0, 6, 0.1)    # 以0.1为单位，生成0-6的数据
y1 = np.sin(x1)

# 绘制图形
plt.plot(x1, y1)
plt.show()

# %% [markdown]
# # 1.6.2 pyplot的功能

# %%
import numpy as np
import matplotlib.pyplot as plt
x2 = np.arange(0, 6, 0.1)
y2 = np.sin(x2)
y3 = np.cos(x2)

# 绘制图形
plt.plot(x2, y2, label="sin")
plt.plot(x2, y3, label="cos", lineStyle="--")   # 用虚线绘制
plt.xlabel("x")  # x轴标签
plt.ylabel("y")  # yz轴标签
plt.title("sin & cos")  # 标题
plt.legend()
plt.show()

# %% [markdown]
# # 1.6.3 显示图像
# pyplot提供了显示图像的方法：
# - imshow()
#
# matplotlib.image模块提供了图像读入的方法：
# - imread()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# 读入图像
img = imread('linlin.jpg')
plt.imshow(img)
plt.show()
